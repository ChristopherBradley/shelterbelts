# %% [markdown]
# # Class Metrics Demo
#
# `class_metrics` calculates the percentage cover in each category from a shelter_categories output,
# summarised across four sheets: Overall, Landcover, Trees, and Shelter.

# %%
from shelterbelts.utils.filepaths import get_filename
from shelterbelts.indices.class_metrics import class_metrics

# Example data: a shelter_categories output (the last pipeline step), so the Shelter sheet
# reflects the sheltered vs unsheltered split by tree type
shelter_file = get_filename('g2_26729_shelter_categories.tif')

# %% [markdown]
# ## Class Metrics

# %%
dfs = class_metrics(shelter_file)
# Out:
# Saved: ./TEST_class_metrics.xlsx

# %%
dfs['Overall']
# Out:
#                                             category_id  pixel_count  \
# label
# Patch Core                                           12        13692
# Unsheltered Grassland                                30         7195
# Grassland sheltered by Trees in Gullies              35         6198
# Grassland sheltered by Non-linear Patches            39         2355
# Trees in Gullies                                     15         2219
# Unsheltered Cropland                                 40         1750
# Non-linear Patches                                   19         1467
# Patch Edge                                           13         1195
# Grassland sheltered by Linear Patches                38         1134
# Grassland sheltered by Patch Edge                    33          927
# Trees next to Roads                                  17          830
# Grassland sheltered by Trees next to Roads           37          729
# Cropland sheltered by Linear Patches                 48          203
# Linear Patches                                       18          196
# Scattered Trees                                      11          142
# Cropland sheltered by Trees in Gullies               45           56
# Built-up                                             50           31
# Cropland sheltered by Non-linear Patches             49           33
# Permanent water bodies                               80           23
# Sheltered Grassland                                  32           18
# Cropland sheltered by Trees next to Roads            47            3
# Cropland sheltered by Patch Edge                     43            5
#
#                                             percentage landcover_group
# label
# Patch Core                                       33.89           Trees
# Unsheltered Grassland                            17.81       Grassland
# Grassland sheltered by Trees in Gullies          15.34       Grassland
# Grassland sheltered by Non-linear Patches         5.83       Grassland
# Trees in Gullies                                  5.49           Trees
# Unsheltered Cropland                              4.33        Cropland
# Non-linear Patches                                3.63           Trees
# Patch Edge                                        2.96           Trees
# Grassland sheltered by Linear Patches             2.81       Grassland
# Grassland sheltered by Patch Edge                 2.29       Grassland
# Trees next to Roads                               2.05           Trees
# Grassland sheltered by Trees next to Roads        1.80       Grassland
# Cropland sheltered by Linear Patches              0.50        Cropland
# Linear Patches                                    0.49           Trees
# Scattered Trees                                   0.35           Trees
# Cropland sheltered by Trees in Gullies            0.14        Cropland
# Built-up                                          0.08        Built-up
# Cropland sheltered by Non-linear Patches          0.08        Cropland
# Permanent water bodies                            0.06           Water
# Sheltered Grassland                               0.04       Grassland
# Cropland sheltered by Trees next to Roads         0.01        Cropland
# Cropland sheltered by Patch Edge                  0.01        Cropland

# %%
dfs['Landcover']
# Out:
#                  pixel_count  percentage
# landcover_group
# Trees                  19741       48.86
# Grassland              18556       45.92
# Cropland                2050        5.07
# Built-up                  31        0.08
# Water                     23        0.06

# %%
dfs['Trees']
# Out:
#                      pixel_count  percentage
# label
# Patch Core                 13692       69.36
# Trees in Gullies            2219       11.24
# Non-linear Patches          1467        7.43
# Patch Edge                  1195        6.05
# Trees next to Roads          830        4.20
# Linear Patches               196        0.99
# Scattered Trees              142        0.72

# %%
dfs['Shelter']
# Out:
#            Sheltered  Unsheltered
# Grassland      61.23        38.77
# Cropland       14.63        85.37
# Total          56.59        43.41

# %% [markdown]
# ## Command Line Interface

# %%
# !python -m shelterbelts.indices.class_metrics --help
# Out:
# usage: class_metrics.py [-h] [--outdir OUTDIR] [--stub STUB] [--no-save-excel]
#                         shelter_data
#
# positional arguments:
#   shelter_data     Integer tif file generated by shelter_categories.py
#
# options:
#   -h, --help       show this help message and exit
#   --outdir OUTDIR  Output directory for saving results (default: current
#                    directory)
#   --stub STUB      Prefix for output filenames (default: TEST)
#   --no-save-excel  Disable Excel output (default: enabled)

# %%
# !python -m shelterbelts.indices.class_metrics {shelter_file} --stub command_line
# Out:
# Saved: ./command_line_class_metrics.xlsx

# %% [markdown]
# ### Cleanup
# Remove the output files created by this notebook

# %%
# !rm *.xlsx
